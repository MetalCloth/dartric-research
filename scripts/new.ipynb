# %%
from sqlalchemy import create_engine,text

# %%
engine=create_engine("postgresql://postgres:shivanshkimkc@db.ywftdjkjdchwmnmytrjj.supabase.co:5432/postgres")

# %%
some_sql="""SELECT SUM(n_live_tup) AS total_rows
FROM pg_stat_user_tables;"""

# %%
import os
from supabase import create_client,Client

# %%
engine=create_engine("postgresql://postgres:shivanshkimkc@db.ywftdjkjdchwmnmytrjj.supabase.co:5432/postgres")
